# %%
import pyodbc
import pandas as pd

# %%
datos = pd.read_csv('All Electronics.csv')
datos
# Out:
#                                                    name        main_category  \
# 0     Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  tv, audio & cameras
# 1     OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  tv, audio & cameras
# 2     OnePlus Bullets Z2 Bluetooth Wireless in Ear E...  tv, audio & cameras
# 3     Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  tv, audio & cameras
# 4     OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  tv, audio & cameras
# ...                                                 ...                  ...
# 9595  PALAY® BTS Backpack For Boys Kpop BTS Bangtan ...  tv, audio & cameras
# 9596  MOCA iPad Air 5th Generation Case 2022 / iPad ...  tv, audio & cameras
# 9597  ZEBRONICS Zeb-Sound Bomb 5 TWS V5.0 Bluetooth ...  tv, audio & cameras
# 9598  LINQS® Original NXP Chip | Waterproof NFC Tag ...  tv, audio & cameras
# 9599  Pragati Systems® Medium Grain 24x36 Inch 10 Oz...  tv, audio & cameras
#
# ...

# %%
lista_valores = datos.values.tolist()
lista_valores
# Out:
# [['Redmi 10 Power (Power Black, 8GB RAM, 128GB Storage)',
#   'tv, audio & cameras',
#   'All Electronics',
#   'https://m.media-amazon.com/images/I/81eM15lVcJL._AC_UL320_.jpg',
#   'https://www.amazon.in/Redmi-Power-Black-128GB-Storage/dp/B09Y64H8VS/ref=sr_1_4?qid=1679133649&s=electronics&sr=1-4',
#   '4.0',
#   '965',
#   '₹10,999',
#   '₹18,999'],
#  ['OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM, 128GB Storage)',
#   'tv, audio & cameras',
#   'All Electronics',
#   'https://m.media-amazon.com/images/I/71AvQd3VzqL._AC_UL320_.jpg',
#   'https://www.amazon.in/OnePlus-Nord-Lite-128GB-Storage/dp/B09WQYFLRX/ref=sr_1_5?qid=1679133649&s=electronics&sr=1-5',
#   '4.3',
#   '113,956',
#   '₹18,999',
#   '₹19,999'],
#  ['OnePlus Bullets Z2 Bluetooth Wireless in Ear Earphones with Mic, Bombastic Bass - 12.4 Mm Drivers, 10 Mins Charge - 20 Hrs...',
#   'tv, audio & cameras',
#   'All Electronics',
#   'https://m.media-amazon.com/images/I/51UhwaQXCpL._AC_UL320_.jpg',
# ...

# %%
import pyodbc

server = 'BRYANPC\SQLEXPRESS'
db_name = 'PROYECTO_ANALISIS'

conexion = pyodbc.connect(driver = '{SQL server}', host = server, database = db_name)
print("Conexion Exitosa")
# Out:
# Conexion Exitosa

# %%
cursor = conexion.cursor()
cursor.execute('CREATE TABLE PRODUCTOS_AMAZON(name VARCHAR(MAX), main_category VARCHAR(20), sub_category VARCHAR(20), image VARCHAR(MAX), link VARCHAR(MAX), ratings DOUBLE, no_of_ratings INTEGER, discount_price VARCHAR(8), actual_price VARCHAR(8))')
cursor.execute('INSERT INTO PRODUCTOS_AMAZON VALUES (?,?,?,?,?,?,?,?,?)', lista_valores)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\bryan\OneDrive\Escritorio\csv\script_subida.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/bryan/OneDrive/Escritorio/csv/script_subida.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> cursor = conexion.cursor()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bryan/OneDrive/Escritorio/csv/script_subida.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> cursor.execute('CREATE TABLE PRODUCTOS_AMAZON(name VARCHAR(MAX), main_category VARCHAR(20), sub_category VARCHAR(20), image VARCHAR(MAX), link VARCHAR(MAX), ratings DOUBLE, no_of_ratings INTEGER, discount_price VARCHAR(8), actual_price VARCHAR(8))')
#       <a href='vscode-notebook-cell:/c%3A/Users/bryan/OneDrive/Escritorio/csv/script_subida.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> cursor.execute('INSERT INTO PRODUCTOS_AMAZON VALUES (?,?,?,?,?,?,?,?,?)', lista_valores)
#
# ...

# %%
conexion.close()
